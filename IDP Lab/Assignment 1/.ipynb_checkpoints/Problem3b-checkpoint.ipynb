# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 401
t = np.linspace(-2 , 2 , N)
w = np.linspace(-np.pi , np.pi , N)

def f(t,a=1):
    return np.exp(-(a**2)*np.pi*t**2)
def g(t):
    return np.cos(2*np.pi*t) + 0.5*np.sin(4*np.pi*t)

# %% [raw]
# As we can see the curvature of the curve increases on increasing a

# %%
Rtime = 0.2
def p(t , Rtime):
    L=[]
    for i in t:
       
        if abs(i/Rtime - round(i/Rtime)) < 0.01:
            L.append(1)
        else:
            L.append(0)
    return np.array(L)
    

plt.plot(t,p(t , Rtime))
plt.show()
print("Impulse Train P(t) for sampling")
# Out:
# Impulse Train P(t) for sampling

# %%
x = g(t)*p(t,Rtime)
x1 = []
N = np.linspace(-10,10 , 21)
for i in x:
    
    if i!=0:
        x1.append(i)
x = np.array(x1)

plt.scatter(N , x)
plt.xlabel('n')
plt.ylabel('f[n]')
plt.show()
print("Sampled Signal")
# Out:
# Sampled Signal

# %% [raw]
# Approximate Integral : Σ f(n*Rtime)e^(-2pi * i *s * n * Rtime) from n= -infinity to +infinity

# %%
L = 3.2
n = L/(2*Rtime)

print(p)
n = int(n)
print(x)
x1 = x[11-n:11+n] 
N1 = N[11-n:11+n] 
plt.scatter(N1,x1)
plt.xlabel('n')
plt.ylabel('y[n]')
plt.show()
print("Signal after applying the window function")
# Out:
# <function p at 0x7f70c0664268>
# [ 1.          0.60290962 -1.28454525 -0.33348874  0.01512437  1.
#   0.60290962 -1.28454525 -0.33348874  0.01512437  1.          0.60290962
#  -1.28454525 -0.33348874  0.01512437  1.          0.60290962 -1.28454525
#  -0.33348874  0.01512437  1.        ]
# Signal after applying the window function

# %% [raw]
# Approximate Integral : Σ f(nRtime)e^(-2pi * i * s * n * Rtime) from n= -L/(2*Rtime) to +L/(2*Rtime)

# %%
Rfreq = 0.4
m = L/Rfreq + 1
fx = np.fft.fftn(x1,int(m))
plt.scatter(np.linspace(-m//2 , m//2 , m) , np.abs(fx))
plt.xlabel('m')
plt.ylabel('Ff[m]')
plt.show()
print("FT of sampled signal further sampled in frequency domain")
# Out:
# /home/aayush/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   after removing the cwd from sys.path.
# FT of sampled signal further sampled in frequency domain

# %% [raw]
# Approximate Expression : Ff(mRfreq) =  Σ f(nRtime)e^(-2pi * i * m * Rfreq * n * Rtime) from n= -L/(2*Rtime) to +L/(2*Rtime)

# %% [raw]
# Total Samples stored in Time Domain = (L/Rtime) + 1
# Total Samples stored in Frequency Domain = (L/Rfreq) + 1

# %%
def w2(t):
    k = []
    for i in t:
        
    
        
        if abs(i)<= L/2:
            
            k.append(1- (2*abs(i)/L))
        else:
            k.append(0)
            
    return np.array(k)

def w3(t):
    k = []
    for i in np.sin(2*np.pi*t/L)**2:
        
    
        
        if abs(i)<= L/2:
            
            k.append(i)
        else:
            k.append(0)
            
    return np.array(k)

f2 = f(t)*w2(t)
f3 = f(t)*w3(t)

# %%
y2 = f2*p(t,Rtime)
y3 = f3*p(t,Rtime)
x1 = []
N = np.linspace(-10,10 , 21)
for i in y2:
    
    if i!=0:
        x1.append(i)
y2 = np.array(x1)
x1 = []
N = np.linspace(-10,10 , 21)
for i in y3:
    
    if i!=0:
        x1.append(i)
y3 = np.array(x1)

# %%
plt.scatter(np.linspace(-m//2 , m//2 , m) , np.fft.fftn(y2,int(m)))
plt.xlabel('m')
plt.ylabel('Ff[m]')

plt.show()
print("DFT with window function w2")
plt.scatter(np.linspace(-m//2 , m//2 , m) , np.fft.fftn(y3,int(m)))
plt.xlabel('m')
plt.ylabel('Ff[m]')

plt.show()
print("DFT with window function w3")
# Out:
# /home/aayush/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   """Entry point for launching an IPython kernel.
# /home/aayush/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py:591: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/aayush/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   import sys
# DFT with window function w2
# DFT with window function w3
